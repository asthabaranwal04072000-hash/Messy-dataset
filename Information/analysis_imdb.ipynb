# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\astha\Messy-dataset\Information\messy_IMDB_dataset.csv",
    sep=";",
    encoding="latin1")

df.head(20)
# Out:
#    IMBD title ID                                     Original titlÊ  \
# 0      tt0111161                           The Shawshank Redemption
# 1      tt0068646                                      The Godfather
# 2      tt0468569                                    The Dark Knight
# 3      tt0071562                             The Godfather: Part II
# 4      tt0110912                                       Pulp Fiction
# 5      tt0167260      The Lord of the Rings: The Return of the King
# 6      tt0108052                                   Schindler's List
# 7      tt0050083                                       12 Angry Men
# 8      tt1375666                                          Inception
# 9      tt0137523                                         Fight Club
# 10     tt0109830                                       Forrest Gump
# 11     tt0120737  The Lord of the Rings: The Fellowship of the Ring
# 12     tt0060196                    Il buono, il brutto, il cattivo
# ...

# %%
df.shape
# Out:
# (101, 12)

# %%
df.columns
# Out:
# Index(['IMBD title ID', 'Original titlÊ', 'Release year', 'Genrë¨', 'Duration',
#        'Country', 'Content Rating', 'Director', 'Unnamed: 8', 'Income',
#        ' Votes ', 'Score'],
#       dtype='str')

# %%
df["Unnamed: 8"].unique()
# Out:
# array([nan])

# %%
df = df.drop(columns = ["Unnamed: 8"])

# %%
df = df.rename(columns = {'IMBD title ID': 'imdb_title_id',
                          'Original titlÊ': 'original_title',
                          'Release year': 'release_year',
                          'Genrë¨': 'genre',
                          'Duration': 'duration',
                          'Country': 'country', 
                          'Content Rating': 'content_rating', 
                          'Director': 'director', 
                          'Income': 'income',
                          ' Votes ': 'votes',
                          })

# %%
df.columns
# Out:
# Index(['imdb_title_id', 'original_title', 'release_year', 'genre', 'duration',
#        'country', 'content_rating', 'director', 'income', 'votes', 'Score'],
#       dtype='str')
